# %%
import os
from spotipy import Spotify
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# %% [markdown]
# # Login

# %%
# ---- PLACEHOLDERS ----
SPOTIPY_CLIENT_ID = ""
SPOTIPY_CLIENT_SECRET = ""

# This MUST match what you set in your Spotify Developer Dashboard for your app
SPOTIPY_REDIRECT_URI = "http://127.0.0.1:8888/callback"

# Scopes needed:
# - user-library-read: read Liked Songs / Saved Tracks
# - playlist-read-private: read your private playlists
# - playlist-read-collaborative: read collaborative playlists you can access
SCOPE = "user-library-read playlist-read-private playlist-read-collaborative"

sp = Spotify(auth_manager=SpotifyOAuth(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET,
    redirect_uri=SPOTIPY_REDIRECT_URI,
    scope=SCOPE,
    open_browser=True
))

me = sp.current_user()
print("Logged in as:", me.get("display_name"), "| user_id:", me.get("id"))
# Out:
# Logged in as: jeffchoize | user_id: jeffchoize

# %%
def paginate_items(first_page: dict, item_key: str = "items"):
    """
    Spotify API responses usually look like:
    { items: [...], next: 'url or None', ... }
    Spotipy provides sp.next(page) to fetch subsequent pages.
    """
    page = first_page
    while True:
        for it in page.get(item_key, []):
            yield it
        if page.get("next"):
            page = sp.next(page)
        else:
            break

# %% [markdown]
# # Liked Songs

# %%
def liked_songs_df(limit=50):
    first = sp.current_user_saved_tracks(limit=limit, offset=0)  # /me/tracks  [oai_citation:4‡Spotify for Developers](https://developer.spotify.com/documentation/web-api/reference/get-users-saved-tracks?utm_source=chatgpt.com)
    rows = []
    for item in paginate_items(first, "items"):
        t = item.get("track") or {}
        if not t:  # sometimes null
            continue

        artists = ", ".join(a["name"] for a in t.get("artists", []))
        album = (t.get("album") or {}).get("name")
        release_date = (t.get("album") or {}).get("release_date")

        rows.append({
            "source": "liked_songs",
            "source_playlist": "Liked Songs",
            "track_name": t.get("name"),
            "artists": artists,
            "album": album,
            "release_date": release_date,
            "spotify_url": (t.get("external_urls") or {}).get("spotify"),
        })

    return pd.DataFrame(rows)

df_liked = liked_songs_df(10)
df_liked.head(), len(df_liked)
# Out:
# (        source source_playlist                      track_name  \
#  0  liked_songs     Liked Songs  West End Girls - 2018 Remaster
#  1  liked_songs     Liked Songs   All Quiet On The Frontal Lobe
#  2  liked_songs     Liked Songs                     Foolish Man
#  3  liked_songs     Liked Songs                     Hello World
#  4  liked_songs     Liked Songs                      Slow Break
#
#                  artists                                              album  \
#  0         Pet Shop Boys  Please: Further Listening 1984 - 1986 (2018 Re...
#  1  ||||||||||||||||||||                      All Quiet On The Frontal Lobe
#  2                Jack J                                        Blue Desert
#  3               dBridge                                        Hello World
#  4                 Torus                                     Summer of Love
#
#    release_date                                        spotify_url
#  0   1986-03-24  https://open.spotify.com/track/2Di0qFNb7ATroCG...
#  1   2025-12-19  https://open.spotify.com/track/4ZfKPyPbTwPq1cG...
#  2   2024-11-01  https://open.spotify.com/track/77Kvpeoj0zsstt1...
#  3   2025-10-24  https://open.spotify.com/track/6m7r0FOVexZital...
#  4   2025-09-13  https://open.spotify.com/track/0sBTQDPixHEdCWA...  ,
#  1904)

# %% [markdown]
# # Playlist

# %%
def my_playlists():
    first = sp.current_user_playlists(limit=50, offset=0)  # /me/playlists  [oai_citation:5‡Spotify for Developers](https://developer.spotify.com/documentation/web-api/reference/get-a-list-of-current-users-playlists?utm_source=chatgpt.com)
    playlists = []
    for pl in paginate_items(first, "items"):
        if pl["owner"]["id"] == 'jeffchoize':
            playlists.append({
                "playlist_id": pl.get("id"),
                "playlist_name": pl.get("name"),
                "owner_id": (pl.get("owner") or {}).get("id"),
                "public": pl.get("public"),
                "collaborative": pl.get("collaborative"),
                "tracks_total": (pl.get("tracks") or {}).get("total"),
            })
    return pd.DataFrame(playlists)

playlists = my_playlists()
len(playlists)
# Out:
# 54

# %%
playlists
# Out:
#                playlist_id                            playlist_name  \
# 0   6P8RM1FHglFUAt9lNSREzE                             revive inspo
# 1   3W2MRkWLeu5cNvkggN6Qvi                                    2025上
# 2   6Xfxz5x1esA26SQB5Yo3Nm  quiet avant-garde tuesday afternoon (2)
# 3   1pGDklI9TjMdTtBIHOcBTe                      shot of bittersweet
# 4   1q3E8ykuuctV9CDPbqEQkq                                     RHow
# 5   2vmdORk0mJV1LUyktpRXtR                               seems nice
# 6   5wVOwGyBlT5rPwWTSqTj53                            Vampire State
# 7   4AXRu49y3m2HqhsUcErSl9                          My Playlist #47
# 8   2wyF7Poewtx05AomiYvD0r                                SonicDict
# 9   2lfLW8qjQ80BGH1r8wci06                                     202E
# 10  2Z2yskUsESmC33bjHWWajt                                   the 10
# 11  39THlWY1NjivcqlZXRgSoK                              Brainwashed
# 12  7lJtUtsdRzR8T0FlhdRlgi                                        2
# 13  4ciPpOCmX3z3vvQgvnOpnU                                       h2
# 14  16KmvzH2W7dAqMHtYUYVaW                              Aphex piano
# 15  6ySKlLbbYcwjvqqo0HHDbs                                       h1
# 16  3HOn1jId6WtqXbFOa6Any8                                  IRONNET
# 17  6oOjXtCLG6Rzo81U1Hqb8G                                     rage
# 18  3caJfdpSu4tRAreCPOCzvK                                down time
# 19  3BF2Ji5CuwCtAAAMjtDL4Z                                  newlist
# 20  2QjKTsJMt6EueMsGXI92kd                                  outrage
# 21  1J4HxUYDl5bNwgYpmIcnrI                         still hop in 20s
# 22  2r49LrhoA2fwyKZbUQRxeT                         E30 on the couch
# 23  02kJxzPp0PQWjvVADFbtQ7                        E30 on the groove
# 24  3Eoxb8xWNRUHgpsydAYauN                          E30 on the mood
# 25  6L6uADZsEYDmukCuxe5cKI                                remix m b
# 26  1b98WYsYWd59oUSh8oj6JG                                    track
# 27  2Lsc75Gy44SNTnSFDu2b7r                           nostalgia hits
# 28  0gp8fxxWE04lip4FA5kRtO                               just met n
# 29  4TESuKLUIloM6AELC2eiqk                     FKJ – Ylang Ylang EP
# 30  3YG2vMKCUIJS48M6nvPPDu                              Upside Down
# 31  2sUCfDfVQHGOC6c1ULBF0V                                        叁
# 32  64AFMkUMBKSBXN640KRQMG                   sweet tone in ur voice
# 33  6FRKND1jZ79UdyvjU9dGay                                  sweetie
# 34  1SnLcp8V5sFsryK5mYdtke                     Mac Ayres – Juicebox
# 35  6eowWADPa2k9xBbVHTeee2                               Drive Safe
# 36  42sgmq0yp6SBqXANWTCks2                                     2019
# 37  4T3ThhYC69JRJSnW92Gcie                  Various Artists – .Wave
# 38  6amAhZAadkrErDiraABCUo          Various Artists – .Wave, Vol. 2
# 39  4LJmKUQ9NgqK4qjFnSXRa8                              Chon – Chon
# 40  0obKzeSRAy16BAT1IfAEY9                                      Tec
# 41  6JTMlGpB6j97OO6YfsSXTy                                Self made
# 42  7tGOD2uTVGjep0aoU6AXLA                         Liked from Radio
# 43  53gnvgRbGiut9WS0iqXNb8                                      tom
# 44  5FYsIHOzZyJM73oWhTLqrQ                                    llihc
# 45  0VqQPT1duuQ0V51hCC1S6P    The Dali Thundering Concept – Savages
# 46  5txKPGrJu3NYumYCmiw3zZ                                 Pure med
# 47  4sCkD7zU7KQg6GcwZ5FGkU                          kuai le jia shi
# 48  4FtwEhmwn38H7d3Ai5N2uf                                     funk
# 49  0Zrrorhsr1dFy5nfDOzOfD                        Techdeath is life
# 50  6oTOFevioUq17DQ1IukNJy                                    indie
# 51  5OkgldryBflHiEvhgmXSTY                                  Electro
# 52  2UfAedYuH9Ev3JHodM7eRt                                      Pop
# 53  3Yjoq7kgEh3nesVllGOHXN                                   hiphop
#
#       owner_id  public  collaborative  tracks_total
# 0   jeffchoize   False          False             8
# 1   jeffchoize    True          False            63
# 2   jeffchoize    True          False            50
# 3   jeffchoize   False          False            11
# 4   jeffchoize   False          False            12
# 5   jeffchoize   False          False           151
# 6   jeffchoize    True          False           139
# 7   jeffchoize    True          False             7
# 8   jeffchoize   False          False            64
# 9   jeffchoize   False          False            13
# 10  jeffchoize    True          False           155
# 11  jeffchoize    True          False            10
# 12  jeffchoize   False          False            18
# 13  jeffchoize   False          False             6
# 14  jeffchoize    True          False             7
# 15  jeffchoize   False          False            57
# 16  jeffchoize   False          False           120
# 17  jeffchoize   False          False            21
# 18  jeffchoize    True          False            11
# 19  jeffchoize   False          False           191
# 20  jeffchoize    True           True            36
# 21  jeffchoize    True          False            45
# 22  jeffchoize    True          False            38
# 23  jeffchoize    True          False            48
# 24  jeffchoize    True          False           121
# 25  jeffchoize    True          False             3
# 26  jeffchoize    True          False            75
# 27  jeffchoize    True          False            11
# 28  jeffchoize    True          False            12
# 29  jeffchoize    True          False             6
# 30  jeffchoize    True          False            10
# 31  jeffchoize    True          False             3
# 32  jeffchoize    True          False             6
# 33  jeffchoize    True          False            14
# 34  jeffchoize    True          False            16
# 35  jeffchoize    True          False            25
# 36  jeffchoize    True          False            38
# 37  jeffchoize    True          False            10
# 38  jeffchoize    True          False            16
# 39  jeffchoize    True          False            12
# 40  jeffchoize    True          False            23
# 41  jeffchoize    True          False             8
# 42  jeffchoize    True          False             4
# 43  jeffchoize    True          False             4
# 44  jeffchoize    True          False            20
# 45  jeffchoize    True          False            29
# 46  jeffchoize    True          False            10
# 47  jeffchoize    True          False            29
# 48  jeffchoize    True          False             6
# 49  jeffchoize    True          False            23
# 50  jeffchoize    True          False            12
# 51  jeffchoize    True          False            25
# 52  jeffchoize    True          False            17
# 53  jeffchoize    True          False            11

# %%
def playlist_tracks_df(playlist_id: str, playlist_name: str, limit=100):
    # Get Playlist Items  [oai_citation:6‡Spotify for Developers](https://developer.spotify.com/documentation/web-api/reference/get-playlists-tracks?utm_source=chatgpt.com)
    first = sp.playlist_items(
        playlist_id,
        limit=limit,
        offset=0,
        additional_types=("track",)
    )

    rows = []
    for item in paginate_items(first, "items"):
        t = item.get("track") or {}
        # skip non-tracks (episodes) or removed items
        if not t or t.get("type") != "track":
            continue

        artists = ", ".join(a["name"] for a in t.get("artists", []))
        album = (t.get("album") or {}).get("name")
        release_date = (t.get("album") or {}).get("release_date")

        rows.append({
            "source": "liked_songs",
            "source_playlist": "Liked Songs",
            "track_name": t.get("name"),
            "artists": artists,
            "album": album,
            "release_date": release_date,
            "spotify_url": (t.get("external_urls") or {}).get("spotify"),
        })

    return pd.DataFrame(rows)

# Pull all playlists (can take a bit if you have many)
dfs_by_playlist = {}
for pl in playlists:
    pid, pname = pl["playlist_id"], pl["playlist_name"]
    dfs_by_playlist[pname] = playlist_tracks_df(pid, pname)

sum(len(df) for df in dfs_by_playlist.values()), list(dfs_by_playlist.keys())[:5]

# %% [markdown]
# # Album

# %%
def get_saved_albums_df(limit=50):
    """
    Returns a DataFrame of your saved albums (Library > Albums).
    """
    first = sp.current_user_saved_albums(limit=limit, offset=0)
    rows = []

    for item in paginate_items(first, "items"):
        album = item.get("album") or {}
        if not album:
            continue

        artists = ", ".join(a["name"] for a in album.get("artists", []))
        spotify_url = (album.get("external_urls") or {}).get("spotify")

        rows.append({
            "added_at": item.get("added_at"),
            "album_name": album.get("name"),
            "artist": artists,
            "release_date": album.get("release_date"),
            "album_type": album.get("album_type"),          # album / single / compilation
            "total_tracks": album.get("total_tracks"),
            "spotify_url": spotify_url,
        })

    return pd.DataFrame(rows)

df_saved_albums = get_saved_albums_df()

# %%
len(df_saved_albums)
# Out:
# 187

# %%
df_saved_albums.sort_values('added_at', ascending=False)
# Out:
#                  added_at                                       album_name  \
# 0    2026-01-27T14:31:42Z                                      Blue Desert
# 4    2026-01-10T20:55:35Z                                    Mekong Ballad
# 28   2025-12-16T04:32:31Z                                      24/7 Heaven
# 18   2025-12-14T18:22:51Z                        Algorithmic Accompaniment
# 29   2025-12-13T02:32:04Z  Lazarus (Adult Swim Original Series Soundtrack)
# ..                    ...                                              ...
# 182  2018-07-13T08:45:55Z                          Where Owls Know My Name
# 183  2018-06-11T02:02:36Z                                               II
# 184  2018-04-11T05:55:09Z                                          Augment
# 185  2018-04-04T05:45:42Z                    Lost Forever // Lost Together
# 186  2018-03-28T22:11:17Z                                            Clear
#
#                  artist release_date album_type  total_tracks  \
# 0                Jack J   2024-11-01      album            11
# 4              COLA REN   2025-11-05     single             5
# 28            trickpony   2025-12-15      album             6
# 18   Nueen, Jason Kolàr   2025-08-19      album            12
# 29    Kamasi Washington   2025-04-11      album            11
# ..                  ...          ...        ...           ...
# 182     Rivers of Nihil   2018-03-16      album            10
# 183       Vale Of Pnath   2016-06-10      album             8
# 184                ERRA   2013-10-29      album            12
# 185          Architects   2014-03-11      album            11
# 186           Periphery   2014-01-28      album             7
#
#                                            spotify_url
# 0    https://open.spotify.com/album/1H96rR2NE8XkXZw...
# 4    https://open.spotify.com/album/35BgR7SFHZQVTid...
# 28   https://open.spotify.com/album/4cyKKwiZ9g85rxT...
# 18   https://open.spotify.com/album/5sEmK4xcdrfcKOg...
# 29   https://open.spotify.com/album/5gD3tPSWfnzu1XW...
# ..                                                 ...
# 182  https://open.spotify.com/album/6Ue1iqByWrHTVFU...
# 183  https://open.spotify.com/album/6DmxTvjRTX1X3oM...
# 184  https://open.spotify.com/album/0SHApkUnsJkdt6a...
# 185  https://open.spotify.com/album/6ut947CLkGJcmiF...
# 186  https://open.spotify.com/album/5fw2qgFrQahpaRU...
#
# [187 rows x 7 columns]

# %%
from pathlib import Path

out_xlsx = Path("spotify_library_export.xlsx")

with pd.ExcelWriter(out_xlsx, engine="openpyxl") as writer:
    # Sheet 1: liked songs
    df_liked.to_excel(writer, sheet_name="Liked Songs", index=False)

    df_saved_albums.to_excel(writer, sheet_name="Saved Album", index=False)

    # Other sheets: playlists
    # for name, df in dfs_by_playlist.items():
    #     # Excel sheet name max length is 31 chars; also avoid illegal chars
    #     safe_name = name.replace("/", "_")[:31] or "Playlist"
    #     df.to_excel(writer, sheet_name=safe_name, index=False)

out_xlsx
# Out:
# PosixPath('spotify_library_export.xlsx')
